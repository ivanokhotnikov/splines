# %%
import re
from math import ceil, cos, sin, tan, pi, radians, sqrt, degrees

# %%
def print_drawing_data(units='imperial'):
    if units == 'imperial':
        if spline_type == 'INT':
            print(
                f'{spec}',
                f'Number of teeth {teeth}',
                f'Pitch {diametral_pitch}/{stub_pitch}',
                f'Pressure angle {round(pressure_angle, ndigits=1)}',
                f'Base diameter {round(base_dia, ndigits=6)}',
                f'Pitch diameter {round(pitch_dia, ndigits=6)}',
                f'Max major diameter {round(max_major_int_dia, ndigits=3)}',
                # f'Min major diameter {round(min_major_int_dia, ndigits=3)}',
                f'Form diameter {round(form_dia, ndigits=3)}',
                f'Min minor diameter {round(min_minor_int_dia, ndigits=3)}',
                f'Max minor diameter {round(max_minor_int_dia, ndigits=3)}',
                '__' * 10,
                f'Max actual space width {round(max_act_width, ndigits=4)}',
                # f'Max effective space width {round(max_eff_width, ndigits=4)}',
                # f'Min actual space width {round(min_act_width, ndigits=4)}',
                f'Min effective space width {round(min_eff_width, ndigits=4)}',
                '__' * 10,
                f'Max measurement between pins {round(max_pin_measurement, ndigits=4)}',
                # f'Min measurement over pins {round(min_int_measurement, ndigits=3)}',
                f'Pin diameter {round(pin_dia, ndigits=4)}',
                # f'Fillet radius {round(int_root_rad, ndigits=1)}\n',
                sep='\n')
        elif spline_type == 'EXT':
            print(
                f'{spec}',
                f'Number of teeth {teeth}',
                f'Pitch {diametral_pitch}/{stub_pitch}',
                f'Pressure angle {round(pressure_angle, ndigits=1)}',
                f'Base diameter {round(base_dia, ndigits=6)}',
                f'Pitch diameter {round(pitch_dia, ndigits=6)}',
                f'Min major diameter {round(min_major_ext_dia, ndigits=3)}',
                f'Max major diameter {round(max_major_ext_dia, ndigits=3)}',
                f'Form diameter {round(form_dia, ndigits=3)}',
                f'Min minor diameter {round(min_minor_ext_dia, ndigits=3)}',
                # f'Max minor diameter {round(max_minor_ext_dia, ndigits=3)}',
                '__' * 10,
                f'Max effective tooth thickness {round(max_eff_thickness, ndigits=4)}',
                # f'Max actual tooth thickness {round(max_act_thickness, ndigits=4)}',
                # f'Min effective tooth thickness {round(min_eff_thickness, ndigits=4)}',
                f'Min actual tooth thickness {round(min_act_thickness, ndigits=4)}',
                '__' * 10,
                # f'Max measurement over pins {round(max_ext_measurement, ndigits=3)}',
                f'Min measurement over pins {round(min_pin_measurement, ndigits=4)}',
                f'Pin diameter {round(pin_dia, ndigits=4)}',
                # f'Fillet radius {round(ext_root_rad, ndigits=1)}\n',
                sep='\n')
    elif units == 'metric':
        if spline_type == 'INT':
            print(
                f'{spec}',
                f'Number of teeth {teeth}',
                f'Pitch {diametral_pitch}/{stub_pitch}',
                f'Pressure angle {round(pressure_angle, ndigits=1)}',
                f'Base diameter {round(base_dia*25.4, ndigits=4)}',
                f'Pitch diameter {round(pitch_dia*25.4, ndigits=4)}',
                f'Max major diameter {round(max_major_int_dia*25.4, ndigits=3)}',
                # f'Min major diameter {round(min_major_int_dia, ndigits=3)}',
                f'Form diameter {round(form_dia*25.4, ndigits=3)}',
                f'Min minor diameter {round(min_minor_int_dia*25.4, ndigits=3)}',
                f'Max minor diameter {round(max_minor_int_dia*25.4, ndigits=3)}',
                '__' * 10,
                f'Max actual space width {round(max_act_width*25.4, ndigits=3)}',
                # f'Max effective space width {round(max_eff_width, ndigits=4)}',
                # f'Min actual space width {round(min_act_width, ndigits=4)}',
                f'Min effective space width {round(min_eff_width*25.4, ndigits=3)}',
                '__' * 10,
                f'Max measurement between pins {round(max_pin_measurement*25.4, ndigits=3)}',
                # f'Min measurement over pins {round(min_int_measurement, ndigits=3)}',
                f'Pin diameter {round(pin_dia*25.4, ndigits=3)}',
                # f'Fillet radius {round(int_root_rad, ndigits=1)}\n',
                sep='\n')
        elif spline_type == 'EXT':
            print(
                f'{spec}',
                f'Number of teeth {teeth}',
                f'Pitch {diametral_pitch}/{stub_pitch}',
                f'Pressure angle {round(pressure_angle, ndigits=1)}',
                f'Base diameter {round(base_dia*25.4, ndigits=4)}',
                f'Pitch diameter {round(pitch_dia*25.4, ndigits=4)}',
                f'Min major diameter {round(min_major_ext_dia*25.4, ndigits=3)}',
                f'Max major diameter {round(max_major_ext_dia*25.4, ndigits=3)}',
                f'Form diameter {round(form_dia*25.4, ndigits=3)}',
                f'Min minor diameter {round(min_minor_ext_dia*25.4, ndigits=3)}',
                # f'Max minor diameter {round(max_minor_ext_dia, ndigits=3)}',
                '__' * 10,
                f'Max effective tooth thickness {round(max_eff_thickness*25.4, ndigits=3)}',
                # f'Max actual tooth thickness {round(max_act_thickness, ndigits=4)}',
                # f'Min effective tooth thickness {round(min_eff_thickness, ndigits=4)}',
                f'Min actual tooth thickness {round(min_act_thickness*25.4, ndigits=3)}',
                '__' * 10,
                # f'Max measurement over pins {round(max_ext_measurement, ndigits=3)}',
                f'Min measurement over pins {round(min_pin_measurement*25.4, ndigits=3)}',
                f'Pin diameter {round(pin_dia*25.4, ndigits=3)}',
                # f'Fillet radius {round(ext_root_rad, ndigits=1)}\n',
                sep='\n')

# %%
spec = 'EXT FLAT ROOT DIA FIT 12/24 30T 30 CLASS 5 ANSI B92'
# spec = 'INT FLAT ROOT SIDE FIT 16/32 11 30 BS 3550'
# spec = 'EXT 25z x 1,0m x 30R x 6e - ISO 4156'

# %%
spec_list = [
    i for i in re.split(r'x| |/|-|ISO|4156|ANSI|B92|ROOT|FIT|BS|3550|CLASS',
                        spec) if bool(i)
]
if 'ANSI' in spec:
    spline_type, spline_root, spline_fit, diametral_pitch, stub_pitch, teeth, pressure_angle, tol_class = spec_list
    diametral_pitch = float(
        diametral_pitch) if '.' in diametral_pitch else int(diametral_pitch)
    pressure_angle = float(pressure_angle)
    stub_pitch = int(stub_pitch)
    teeth = int(teeth[:-1])
    tol_class = int(tol_class)
elif 'BS' in spec:
    spline_type, spline_root, spline_fit, diametral_pitch, stub_pitch, teeth, pressure_angle = spec_list
    diametral_pitch = float(diametral_pitch)
    pressure_angle = float(pressure_angle)
    teeth = int(teeth)
    stub_pitch = float(stub_pitch)
elif 'ISO' in spec:
    spline_type, teeth, module, pressure_angle, tolerance = spec_list
    teeth = int(teeth[:-1])
    if pressure_angle[-1] == 'R': root = 'fillet'
    if pressure_angle[-1] == 'P': root = 'flat'
    pressure_angle = float(pressure_angle[:-1])
    try:
        module = float(module[:-1])
    except ValueError:
        module = float(module[:-1].replace(',', '.'))
    tolerance_class = int(tolerance[0])
    fit_class = tolerance[1:]

    pitch_dia = module * teeth
    if pitch_dia > 1000:
        raise Exception(
            'The pitch diameter is out of range of fundamental deviations.'
        )

# %%
pitch_dia = teeth / diametral_pitch
base_dia = pitch_dia * cos(radians(pressure_angle))
circular_pitch = pi / float(diametral_pitch)

# %%
# see table 107 ANSI B92.1-1996
maj_min_dia_tolerances_dict = {
    range(1, 3): {
        'TAB': 0.0200,
        'FN': lambda P: round((2000 / P + 250) * 1e-4, ndigits=4)
    },
    range(3, 4): {
        'TAB': 0.0150,
        'FN': lambda P: round((2000 / P + 200) * 1e-4, ndigits=4)
    },
    range(4, 5): {
        'TAB': 0.0100,
        'FN': lambda P: round((2000 / P + 150) * 1e-4, ndigits=4)
    },
    range(5, 6): {
        'TAB': 0.0080,
        'FN': lambda P: round((2000 / P + 130) * 1e-4, ndigits=4)
    },
    range(6, 32): {
        'TAB': 0.0050,
        'FN': lambda P: round((2000 / P + 100) * 1e-4, ndigits=4)
    },
    range(32, 64): {
        'TAB': 0.0030,
        'FN': lambda P: round((2000 / P + 80) * 1e-4, ndigits=4)
    },
    range(64, 160): {
        'TAB': 0.0020,
        'FN': lambda P: round((2000 / P + 70) * 1e-4, ndigits=4)
    },
}

for pitch_range in maj_min_dia_tolerances_dict:
    if diametral_pitch in pitch_range:
        dia_tolerance = maj_min_dia_tolerances_dict[pitch_range]

# %%
# see table 106 ANSI B92.1-1996
allowances_class5 = {
    range(1, 4): {
        'machining': lambda N: round((0.18 * N + 15) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.35 * N + 20) * 1e-4, ndigits=4),
    },
    range(4, 6): {
        'machining': lambda N: round((0.15 * N + 13) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.23 * N + 18) * 1e-4, ndigits=4),
    },
    range(6, 10): {
        'machining': lambda N: round((0.15 * N + 11) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.20 * N + 15) * 1e-4, ndigits=4),
    },
    range(10, 16): {
        'machining': lambda N: round((0.10 * N + 11) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.17 * N + 14) * 1e-4, ndigits=4),
    },
    range(16, 24): {
        'machining': lambda N: round((0.07 * N + 11) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.12 * N + 13) * 1e-4, ndigits=4),
    },
    range(24, 49): {
        'machining': lambda N: round((0.07 * N + 11) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.12 * N + 11) * 1e-4, ndigits=4),
    },
    range(64, 81): {
        'machining': lambda N: round((0.06 * N + 9) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.10 * N + 10) * 1e-4, ndigits=4),
    },
    range(128, 256): {
        'machining': lambda N: round((0.05 * N + 9) * 1e-4, ndigits=4),
        'variations': lambda N: round((0.08 * N + 9) * 1e-4, ndigits=4),
    },
}

for pitch_range in allowances_class5:
    if diametral_pitch in pitch_range:
        tolerances_class5 = allowances_class5[pitch_range]['machining'](
            teeth) + allowances_class5[pitch_range]['variations'](teeth)

if tol_class == 4:
    total_tolerance = 0.71 * tolerances_class5
elif tol_class == 5:
    total_tolerance = tolerances_class5
elif tol_class == 6:
    total_tolerance = 1.40 * tolerances_class5
elif tol_class == 7:
    total_tolerance = 2.00 * tolerances_class5

# %%
# see table 2 ANSI B92.1-1996
rad_form_clearance = min(max(0.001 * pitch_dia, 0.002), 0.01)

# see table 2 ANSI B92.1-1996
form_dia_dict = {
    'EXT': {
        30.0: lambda N, P: (N - 1) / P - 2 * rad_form_clearance,
        37.5: lambda N, P: (N - 0.8) / P - 2 * rad_form_clearance,
        45.0: lambda N, P: (N - 0.6) / P - 2 * rad_form_clearance,
    },
    'INT': {
        'SIDE': lambda N, P: (N + 1) / P + 2 * rad_form_clearance,
        'DIA': lambda N, P: (N + 0.8) / P + 2 * rad_form_clearance - 0.004,
    },
}

# %%
# see table 2 ANSI B92.1-1996
min_minor_dia_dict = {
    'INT': {
        30.0: lambda N, P: (N - 1) / P,
        37.5: lambda N, P: (N - 0.8) / P,
        45.0: lambda N, P: (N - 0.6) / P,
    },
    'EXT': {
        30.0: {
            'FLAT':
            lambda N, P: (N - 1.35) / P - 0.004 - 2 * total_tolerance / tan(
                radians(pressure_angle)),
            'FILLET': {
                range(1, 12 + 1):
                lambda N, P: (N - 1.9) / P - 2 * total_tolerance / tan(
                    radians(pressure_angle)),
                range(16, 160):
                lambda N, P: (N - 2.1) / P - 2 * total_tolerance / tan(
                    radians(pressure_angle)),
            },
        },
        37.5:
        lambda N, P:
        (N - 1.4) / P - 2 * total_tolerance / tan(radians(pressure_angle)),
        45.0:
        lambda N, P:
        (N - 1.1) / P - 2 * total_tolerance / tan(radians(pressure_angle)),
    },
}

# %%
# see tble 107a ANSI B92.1-1996
eff_clearance_dia_fit_dict = {
    range(1, 4): lambda N: round((0.20 * N + 18) * 1e-4, ndigits=4),
    range(4, 6): lambda N: round((0.15 * N + 16) * 1e-4, ndigits=4),
    range(6, 10): lambda N: round((0.10 * N + 14) * 1e-4, ndigits=4),
    range(10, 16): lambda N: round((0.07 * N + 14) * 1e-4, ndigits=4),
}
for pitch_range in eff_clearance_dia_fit_dict:
    if diametral_pitch in pitch_range:
        eff_clearance_dia_fit = eff_clearance_dia_fit_dict[pitch_range](teeth)
    elif diametral_pitch >= 16:
        eff_clearance_dia_fit = 15 * 1e-4

# %%
if spline_type == 'EXT':
    form_dia = form_dia_dict[spline_type][pressure_angle](teeth,
                                                          diametral_pitch)
    min_form_ext_dia = sqrt(
        3 * teeth**2 + (teeth - 0.016 * diametral_pitch - 4.5)**2) / (
            2 * diametral_pitch) if spline_root == 'FLAT' else sqrt(
                3 * teeth**2 + (teeth - 5.359)**2) / (2 * diametral_pitch)
    if pressure_angle == 30.0:
        if spline_fit == 'SIDE':
            max_eff_thickness = 0.5 * circular_pitch
        elif spline_fit == 'DIA':
            max_eff_thickness = 0.5 * circular_pitch - eff_clearance_dia_fit
        if spline_root == 'FILLET':
            for pitch_range in min_minor_ext_dia_dict[spline_type][
                    pressure_angle][spline_root]:
                if diametral_pitch in pitch_range:
                    min_minor_ext_dia = min_minor_ext_dia[spline_type][
                        pressure_angle][spline_root][pitch_range](
                            teeth, diametral_pitch)
        elif spline_root == 'FLAT':
            min_minor_ext_dia = min_minor_dia_dict[spline_type][
                pressure_angle][spline_root](teeth, diametral_pitch)
    elif pressure_angle == 37.5:
        max_eff_thickness = (0.5 * pi + 0.1) / diametral_pitch
        min_minor_ext_dia = min_minor_dia_dict[spline_type][pressure_angle](
            teeth, diametral_pitch)
    elif pressure_angle == 45.0:
        max_eff_thickness = (0.5 * pi + 0.2) / diametral_pitch
        min_minor_ext_dia = min_minor_dia_dict[spline_type][pressure_angle](
            teeth, diametral_pitch)
    if spline_fit == 'SIDE':
        max_major_ext_dia = (teeth + 1) / diametral_pitch
        if spline_root == 'FLAT':
            min_major_ext_dia = max_major_ext_dia - dia_tolerance['FN'](
                diametral_pitch)
            form_ext_dia = max(min_form_ext_dia, form_dia)
        elif spline_root == 'FILLET':
            min_major_ext_dia = max_major_ext_dia - dia_tolerance['TAB']
            form_ext_dia = max(min_form_ext_dia, form_dia)
    elif spline_fit == 'DIA':
        form_ext_dia = max(min_form_ext_dia, form_dia)
        max_major_ext_dia = (teeth + 1) / diametral_pitch - 0.0001
        min_major_ext_dia = max_major_ext_dia - round(
            (3 + 2 * pitch_dia) * 1e-4, ndigits=4)
    min_act_thickness = max_eff_thickness - total_tolerance
    pin_dia = 1.9200 / diametral_pitch
elif spline_type == 'INT':
    form_dia = form_dia_dict[spline_type][spline_fit](teeth, diametral_pitch)
    min_minor_int_dia = min_minor_dia_dict[spline_type][pressure_angle](
        teeth, diametral_pitch)
    max_minor_int_dia = min_minor_int_dia + dia_tolerance['TAB']
    if pressure_angle == 30.0:
        pin_dia = 1.7280 / diametral_pitch
        min_eff_width = pi / (2 * diametral_pitch)
        if spline_root == 'FLAT':
            if spline_fit == 'SIDE':
                max_major_int_dia = (teeth + 1.35) / diametral_pitch + 0.004
            elif spline_fit == 'DIA':
                max_major_int_dia = (teeth + 1) / diametral_pitch
        elif spline_root == 'FILLET':
            max_major_int_dia = (teeth + 1.8) / diametral_pitch
    elif pressure_angle == 37.5:
        pin_dia = 1.7280 / diametral_pitch
        min_eff_width = (0.5 * pi + .1) / (diametral_pitch)
        max_major_int_dia = (teeth + 1.6) / diametral_pitch
    elif pressure_angle == 45.0:
        pin_dia = 1.9200 / diametral_pitch
        max_eff_width = (0.5 * pi + .2) / (diametral_pitch)
        min_major_int_dia = (teeth + 1.4) / diametral_pitch
    max_act_width = min_eff_width + total_tolerance

# %%
involute = lambda alpha: tan(radians(alpha)) - pi * alpha / 180
inverse_involute = lambda x: x**(1 / 3) / (.693357 + .192484 * x**
                                            (2 / 3))

# %%
if spline_type == 'EXT':
    inv_phi_e = min_act_thickness / pitch_dia + (
        involute(pressure_angle) + pin_dia / base_dia - pi / teeth)
    if teeth % 2 == 0:
        min_pin_measurement = base_dia / cos(inverse_involute(inv_phi_e)) + pin_dia
    else:
        min_pin_measurement = base_dia / (cos(
            pi / (2 * teeth) * cos(inverse_involute(inv_phi_e)))) + pin_dia
elif spline_type == 'INT':
    inv_phi_i = max_act_width / pitch_dia + (involute(pressure_angle) -
                                              pin_dia / base_dia)
    if teeth % 2 == 0:
        max_pin_measurement = base_dia / cos(inverse_involute(inv_phi_e)) - pin_dia
    else:
        max_pin_measurement = base_dia / (cos(
            pi / (2 * teeth) * cos(inverse_involute(inv_phi_e)))) - pin_dia

# %%
print_drawing_data(units='imperial')
